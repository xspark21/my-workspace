# %% [markdown]
# # Some practice and test
#
# como se viene diciendo, la importancia de los notebooks es que nos permitan explorar, jugar o practicar con nuestro dataset (si no es muy grande) usualmente uno parte aqui, prueba algunas cosas muestreando y luego generaliza para todo el dataset, en ese caso uno lo lleva a src/ y main.py o donde nos parezca más cómodo.
#
# > recordatorio: no siempre es necesaria tanta ingenieria para poder resolver nuestros problemas, por ejemplo si nuestro dataset ya viene limpio, de sitios como kaggle, no hace falta crear un ecosistema completo que valide los datos. basta con cargar, verificar algunos supuestos y empezar con la parte estadistica
#
# Se puede usar esta carpeta para poder hacer tantos notebooks como se necesiten y seguir probando
#
# >para más informacion de cómo usar los notebooks: revisar los apuntes de `some-notes`

# %%
# puedes importar las funciones que hagas en src o cualquier otra carpeta, revisa el README principal para mas informacion
import polars as pl
from modules import show

#df = pl.read_csv("ruta al archivo csv")
#show(df)

# %% [markdown]
# # About libraries
#
# Se instalan con `uv` y se pueden usar en todo el proyecto sin preocuparse mucho de ese tema, acerca de cómo **hacer** un notebook para EDA, Modelación, Machine Learning, etc. subiré pronto apuntes
